# %% [markdown]
# ## Initialize Notebook

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-32-d1c1bd939e7e> in <module>
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
# ----> 5 import mylib
#       6 sns.set(style="darkgrid")
#
# ModuleNotFoundError: No module named 'mylib'

# %% [markdown]
# # Descriptive Statistics

# %%
df = pd.read_csv("tips.csv")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
(df > 20).any()
# Out:
# total_bill     True
# tip           False
# sex            True
# smoker         True
# day            True
# time           True
# size          False
# dtype: bool

# %%
df.round(2)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
df.sort_values(by='tip', ascending=False)
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4
# 47        32.40   6.00    Male     No   Sun  Dinner     4
# 239       29.03   5.92    Male     No   Sat  Dinner     3
# 88        24.71   5.85    Male     No  Thur   Lunch     2
# 181       23.33   5.65    Male    Yes   Sun  Dinner     2
# 44        30.40   5.60    Male     No   Sun  Dinner     4
# 52        34.81   5.20  Female     No   Sun  Dinner     4
# 85        34.83   5.17  Female     No  Thur   Lunch     4
# 211       25.89   5.16    Male    Yes   Sat  Dinner     4
# ...

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.mean()
# Out:
# total_bill    19.785943
# tip            2.998279
# size           2.569672
# dtype: float64

# %%
np.cumsum(df[['total_bill', 'tip', 'size']])
# Out:
#      total_bill     tip   size
# 0         16.99    1.01    2.0
# 1         27.33    2.67    5.0
# 2         48.34    6.17    8.0
# 3         72.02    9.48   10.0
# 4         96.61   13.09   14.0
# 5        121.90   17.80   18.0
# 6        130.67   19.80   20.0
# 7        157.55   22.92   24.0
# 8        172.59   24.88   26.0
# 9        187.37   28.11   28.0
# 10       197.64   29.82   30.0
# 11       232.90   34.82   34.0
# 12       248.32   36.39   36.0
# 13       266.75   39.39   40.0
# 14       281.58   42.41   42.0
# 15       303.16   46.33   44.0
# 16       313.49   48.00   47.0
# 17       329.78   51.71   50.0
# 18       346.75   55.21   53.0
# 19       367.40   58.56   56.0
# 20       385.32   62.64   58.0
# 21       405.61   65.39   60.0
# 22       421.38   67.62   62.0
# 23       460.80   75.20   66.0
# 24       480.62   78.38   68.0
# 25       498.43   80.72   72.0
# 26       511.80   82.72   74.0
# 27       524.49   84.72   76.0
# 28       546.19   89.02   78.0
# ...

# %%
df.std()
# Out:
# total_bill    8.902412
# tip           1.383638
# size          0.951100
# dtype: float64

# %%
df.skew()
# Out:
# total_bill    1.133213
# tip           1.465451
# size          1.447882
# dtype: float64

# %%
sns.relplot(x="total_bill", y="tip", data=df);

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker", data=df);

# %%
sns.relplot(x="total_bill", y="tip", hue="day", style="time", col = "smoker", data=df);

# %% [markdown]
# Early plots from Seaborn suggest that highest tips typically come at dinner time on a Saturday

# %%
sns.pairplot(df)

# %% [markdown]
# # Regression
#
# Regression explains the relationship between variables (particularly simple linear regression, which deals with two variables) and gives the proportional response of a change in one variable on another variable accoring to the equation *y = mx + c*, where x and y are variables, m is the slope of the line of best fit and c is the y-intercept where x = 0.
#
# This regression analysis with assess the relationship between the total bill and tip amount from the "tips" dataset above, with x representing total bill and y being the tip given.

# %%
#make new dataframe 
dfr = df[['total_bill', 'tip']].copy()

#state columns representing x and y
dfr.rename(columns = {'total_bill':'x (total_bill)', 'tip':'y (tip)'}, inplace=True)

#mean of total bill
dfr['x-mean'] = np.mean(dfr['x (total_bill)'])

#difference between x value and the mean
dfr['x-xbar'] = dfr['x (total_bill)'] - np.mean(dfr['x (total_bill)'])

#same as above for tip/y value
dfr['y-ybar'] = dfr['y (tip)'] - np.mean(dfr['y (tip)'])

#squares
dfr['x-xbar^2'] = np.square(dfr['x-xbar'])
dfr['y-ybar^2'] = np.square(dfr['y-ybar'])
dfr['(x-xbar)*(y-ybar)'] = dfr['x-xbar']*dfr['y-ybar']
dfr.head()
# Out:
#    x (total_bill)  y (tip)     x-mean    x-xbar    y-ybar   x-xbar^2  \
# 0           16.99     1.01  19.785943 -2.795943 -1.988279   7.817295
# 1           10.34     1.66  19.785943 -9.445943 -1.338279  89.225832
# 2           21.01     3.50  19.785943  1.224057  0.501721   1.498316
# 3           23.68     3.31  19.785943  3.894057  0.311721  15.163683
# 4           24.59     3.61  19.785943  4.804057  0.611721  23.078967
#
#    y-ybar^2  (x-xbar)*(y-ybar)
# 0  3.953252           5.559113
# 1  1.790990          12.641304
# 2  0.251724           0.614136
# 3  0.097170           1.213861
# 4  0.374203           2.938744

# %%
ss_x = np.sum(dfr['x-xbar^2'])
ss_y = np.sum(dfr['y-ybar^2'])
s_xy = np.sum(dfr['(x-xbar)*(y-ybar)'])
r = np.sum(s_xy)/np.sqrt(ss_x*ss_y)
sd_x = np.sqrt(ss_x/(dfr.shape[0]-1))
sd_y = np.sqrt(ss_y/(dfr.shape[0]-1))
slope = r*sd_y/sd_x
intercept = np.mean(dfr['y (tip)'])-slope*np.mean(dfr['x (total_bill)'])

# %%
cost = lambda slope,intercept: np.sum([(dfr['y (tip)'][i] - slope * dfr['x (total_bill)'][i] - intercept)**2 for i in range(dfr['y (tip)'].size)])

# %%
print("Cost with m = %5.2f and c = %5.2f: %8.2f" % (slope, intercept, cost(slope, intercept)))
# Out:
# Cost with m =  0.11 and c =  0.92:   252.79

# %%
dfr['Predicted Tip'] = intercept + slope * dfr['x (total_bill)']


dfr['Residual'] = dfr['Predicted Tip'] - dfr['y (tip)']
dfr['RegSq'] = np.square(dfr['Predicted Tip'] - np.mean(dfr['Predicted Tip']))
dfr['ResSq'] = np.square(dfr['Residual'] - np.mean(dfr['Residual']))
dfr.head(10)
# Out:
#    x (total_bill)  y (tip)     x-mean     x-xbar    y-ybar    x-xbar^2  \
# 0           16.99     1.01  19.785943  -2.795943 -1.988279    7.817295
# 1           10.34     1.66  19.785943  -9.445943 -1.338279   89.225832
# 2           21.01     3.50  19.785943   1.224057  0.501721    1.498316
# 3           23.68     3.31  19.785943   3.894057  0.311721   15.163683
# 4           24.59     3.61  19.785943   4.804057  0.611721   23.078967
# 5           25.29     4.71  19.785943   5.504057  1.711721   30.294648
# 6            8.77     2.00  19.785943 -11.015943 -0.998279  121.350992
# 7           26.88     3.12  19.785943   7.094057  0.121721   50.325650
# 8           15.04     1.96  19.785943  -4.745943 -1.038279   22.523971
# 9           14.78     3.23  19.785943  -5.005943  0.231721   25.059462
#
#    y-ybar^2  (x-xbar)*(y-ybar)  Predicted Tip  Residual     RegSq     ResSq
# 0  3.953252           5.559113       2.704636  1.694636  0.086226  2.871792
# ...

# %%
RegSS = np.sum(dfr['RegSq'])
ResSS = np.sum(dfr['ResSq'])
TotalSS = RegSS+ResSS
Rsq = RegSS/TotalSS
RegDof = 1 # Total variables -1
ResDof = df.shape[0]-RegDof-1
TotalDof = RegDof+ResDof
AdjRsq = 1-((1-Rsq)*(TotalDof/ResDof))
StdErr = np.sqrt(ResSS/ResDof)

# %%
ParamValue = [RegSS, ResSS, TotalSS, Rsq, RegDof, ResDof, TotalDof, AdjRsq, StdErr,slope,intercept]
ParamName = ['Regression Sum of Square',
             'Residual Sum of Square',
             'Total Sum of Squares',
             'R Square',
             'Regression Degrees of Freedom',
             'Residual Degrees of Freedom',
             'Total Degrees of Freedom',
             'Adjusted R Square',
             'Standard Error',
             'slope',
             'intercept']

stats = pd.DataFrame(data=ParamValue,index=ParamName,columns=['statistic value'])
print(stats)
# Out:
#                                statistic value
# Regression Sum of Square            212.423733
# Residual Sum of Square              252.788744
# Total Sum of Squares                465.212477
# R Square                              0.456617
# Regression Degrees of Freedom         1.000000
# Residual Degrees of Freedom         242.000000
# Total Degrees of Freedom            243.000000
# Adjusted R Square                     0.454371
# Standard Error                        1.022048
# slope                                 0.105025
# intercept                             0.920270

# %%
plt.figure(figsize=(150,80))
model=sns.lmplot(data=dfr,y='y (tip)',x='x (total_bill)',legend=False, height = 12)
#lmplot good for regression models
# Out:
# C:\Users\Dave\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Discuss regression and stats

# %% [markdown]
# # Analysis
#
# In this section the notebook will investigate the relationships between assorted variables in the tips dataset and the effect they have on one another.

# %%
df['Percentage'] = (df['tip'] / df['total_bill']) * 100
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  Percentage
# 0       16.99  1.01  Female     No  Sun  Dinner     2    5.944673
# 1       10.34  1.66    Male     No  Sun  Dinner     3   16.054159
# 2       21.01  3.50    Male     No  Sun  Dinner     3   16.658734
# 3       23.68  3.31    Male     No  Sun  Dinner     2   13.978041
# 4       24.59  3.61  Female     No  Sun  Dinner     4   14.680765

# %%
df['tpp'] = df['tip'] / df['size'] #tpp = tip per person
df.head().round(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size  Percentage   tpp
# 0       16.99  1.01  Female     No  Sun  Dinner     2        5.94  0.50
# 1       10.34  1.66    Male     No  Sun  Dinner     3       16.05  0.55
# 2       21.01  3.50    Male     No  Sun  Dinner     3       16.66  1.17
# 3       23.68  3.31    Male     No  Sun  Dinner     2       13.98  1.66
# 4       24.59  3.61  Female     No  Sun  Dinner     4       14.68  0.90

# %%
df.sort_values(by='Percentage', ascending=False).round(2)
# Out:
#      total_bill   tip     sex smoker   day    time  size  Percentage   tpp
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2       71.03  2.58
# 178        9.60  4.00  Female    Yes   Sun  Dinner     2       41.67  2.00
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1       32.57  1.00
# 232       11.61  3.39    Male     No   Sat  Dinner     2       29.20  1.70
# 183       23.17  6.50    Male    Yes   Sun  Dinner     4       28.05  1.62
# 109       14.31  4.00  Female    Yes   Sat  Dinner     2       27.95  2.00
# 149        7.51  2.00    Male     No  Thur   Lunch     2       26.63  1.00
# 93        16.32  4.30  Female    Yes   Fri  Dinner     2       26.35  2.15
# 221       13.42  3.48  Female    Yes   Fri   Lunch     2       25.93  1.74
# 51        10.29  2.60  Female     No   Sun  Dinner     2       25.27  1.30
# 181       23.33  5.65    Male    Yes   Sun  Dinner     2       24.22  2.82
# ...

# %%
df.sort_values(by='tpp', ascending=False).round(2)
# Out:
#      total_bill    tip     sex smoker   day    time  size  Percentage   tpp
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3       19.68  3.33
# 88        24.71   5.85    Male     No  Thur   Lunch     2       23.67  2.92
# 181       23.33   5.65    Male    Yes   Sun  Dinner     2       24.22  2.82
# 172        7.25   5.15    Male    Yes   Sun  Dinner     2       71.03  2.58
# 46        22.23   5.00    Male     No   Sun  Dinner     2       22.49  2.50
# 83        32.68   5.00    Male    Yes  Thur   Lunch     2       15.30  2.50
# 73        25.28   5.00  Female    Yes   Sat  Dinner     2       19.78  2.50
# 212       48.33   9.00    Male     No   Sat  Dinner     4       18.62  2.25
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3       23.07  2.17
# 28        21.70   4.30    Male     No   Sat  Dinner     2       19.82  2.15
# 93        16.32   4.30  Female    Yes   Fri  Dinner     2       26.35  2.15
# ...

# %%
sns.relplot(x="total_bill", y="Percentage",  data=df);
